# %%
import os

from lib.tokenizer import Tokenizer
from lib.utils import load_txt_file

# %% [markdown]
# ### Constants and hyperparameters

# %%
# Constants
save_state = True # Save the state of the tokenizer into a file
dataset_path = os.path.join(os.getcwd(), 'dataset', 'input.txt') # Path to the training dataset
output_path = os.path.join(os.getcwd(), 'checkpoints', 'tokenizer.json') # Path into which the tokenized parameters will be saved

# %%
# Hyperparameters
vocab_size = 1024 # The size of the vocabulary
validation_samples = 250 # Number of samples to use for validation

# %% [markdown]
# ### Data loading

# %%
# Load the text file
text = load_txt_file(dataset_path)

# Split the text into training and validation sets
training_text = text[:(len(text) - validation_samples if len(text) > validation_samples else -1)]
validation_text = text[-validation_samples:]

# Print the number of samples in each set
print(f"Training text length: {len(training_text)}")
print(f"Validation text length: {len(validation_text)}")
# Out:
# Training text length: 1115144
# Validation text length: 250

# %% [markdown]
# ### Tokenizer

# %%
# Instantiate the tokenizer
tokenizer = Tokenizer()

# %% [markdown]
# ### Training the tokenizer

# %%
    
# Train the tokenizer
tokenizer.train(text=training_text, vocab_size=vocab_size)
# Out:
# 1/768 --> Merged tokens (101, 32) into token 256
# 2/768 --> Merged tokens (116, 104) into token 257
# 3/768 --> Merged tokens (116, 32) into token 258
# 4/768 --> Merged tokens (115, 32) into token 259
# 5/768 --> Merged tokens (100, 32) into token 260
# 6/768 --> Merged tokens (44, 32) into token 261
# 7/768 --> Merged tokens (111, 117) into token 262
# 8/768 --> Merged tokens (101, 114) into token 263
# 9/768 --> Merged tokens (105, 110) into token 264
# 10/768 --> Merged tokens (121, 32) into token 265
# 11/768 --> Merged tokens (97, 110) into token 266
# 12/768 --> Merged tokens (58, 10) into token 267
# 13/768 --> Merged tokens (111, 114) into token 268
# 14/768 --> Merged tokens (111, 32) into token 269
# 15/768 --> Merged tokens (101, 110) into token 270
# 16/768 --> Merged tokens (10, 10) into token 271
# 17/768 --> Merged tokens (97, 114) into token 272
# 18/768 --> Merged tokens (32, 257) into token 273
# 19/768 --> Merged tokens (111, 110) into token 274
# 20/768 --> Merged tokens (108, 108) into token 275
# 21/768 --> Merged tokens (104, 97) into token 276
# 22/768 --> Merged tokens (44, 10) into token 277
# 23/768 --> Merged tokens (46, 271) into token 278
# 24/768 --> Merged tokens (105, 259) into token 279
# 25/768 --> Merged tokens (101, 115) into token 280
# 26/768 --> Merged tokens (121, 262) into token 281
# 27/768 --> Merged tokens (32, 115) into token 282
# 28/768 --> Merged tokens (116, 269) into token 283
# 29/768 --> Merged tokens (266, 260) into token 284
# 30/768 --> Merged tokens (111, 119) into token 285
# 31/768 --> Merged tokens (101, 97) into token 286
# 32/768 --> Merged tokens (32, 109) into token 287
# 33/768 --> Merged tokens (32, 119) into token 288
# 34/768 --> Merged tokens (111, 102) into token 289
# 35/768 --> Merged tokens (32, 104) into token 290
# 36/768 --> Merged tokens (264, 103) into token 291
# 37/768 --> Merged tokens (111, 109) into token 292
# 38/768 --> Merged tokens (32, 97) into token 293
# 39/768 --> Merged tokens (99, 104) into token 294
# 40/768 --> Merged tokens (257, 256) into token 295
# 41/768 --> Merged tokens (115, 116) into token 296
# 42/768 --> Merged tokens (32, 98) into token 297
# 43/768 --> Merged tokens (110, 111) into token 298
# 44/768 --> Merged tokens (105, 114) into token 299
# 45/768 --> Merged tokens (102, 268) into token 300
# 46/768 --> Merged tokens (118, 256) into token 301
# 47/768 --> Merged tokens (101, 261) into token 302
# 48/768 --> Merged tokens (105, 257) into token 303
# 49/768 --> Merged tokens (273, 256) into token 304
# 50/768 --> Merged tokens (115, 101) into token 305
# 51/768 --> Merged tokens (108, 105) into token 306
# 52/768 --> Merged tokens (84, 104) into token 307
# 53/768 --> Merged tokens (275, 32) into token 308
# 54/768 --> Merged tokens (114, 101) into token 309
# 55/768 --> Merged tokens (97, 258) into token 310
# 56/768 --> Merged tokens (115, 258) into token 311
# 57/768 --> Merged tokens (65, 110) into token 312
# 58/768 --> Merged tokens (73, 32) into token 313
# 59/768 --> Merged tokens (101, 272) into token 314
# 60/768 --> Merged tokens (105, 109) into token 315
# 61/768 --> Merged tokens (105, 116) into token 316
# 62/768 --> Merged tokens (111, 111) into token 317
# 63/768 --> Merged tokens (103, 104) into token 318
# 64/768 --> Merged tokens (97, 116) into token 319
# 65/768 --> Merged tokens (105, 115) into token 320
# 66/768 --> Merged tokens (108, 101) into token 321
# 67/768 --> Merged tokens (263, 32) into token 322
# 68/768 --> Merged tokens (262, 114) into token 323
# 69/768 --> Merged tokens (312, 260) into token 324
# 70/768 --> Merged tokens (39, 259) into token 325
# 71/768 --> Merged tokens (101, 101) into token 326
# 72/768 --> Merged tokens (298, 258) into token 327
# 73/768 --> Merged tokens (109, 265) into token 328
# 74/768 --> Merged tokens (59, 10) into token 329
# 75/768 --> Merged tokens (114, 97) into token 330
# 76/768 --> Merged tokens (46, 10) into token 331
# 77/768 --> Merged tokens (281, 114) into token 332
# 78/768 --> Merged tokens (117, 114) into token 333
# 79/768 --> Merged tokens (276, 258) into token 334
# 80/768 --> Merged tokens (114, 105) into token 335
# 81/768 --> Merged tokens (117, 258) into token 336
# 82/768 --> Merged tokens (108, 260) into token 337
# 83/768 --> Merged tokens (289, 32) into token 338
# 84/768 --> Merged tokens (79, 267) into token 339
# 85/768 --> Merged tokens (101, 260) into token 340
# 86/768 --> Merged tokens (108, 97) into token 341
# 87/768 --> Merged tokens (105, 258) into token 342
# 88/768 --> Merged tokens (114, 111) into token 343
# 89/768 --> Merged tokens (263, 256) into token 344
# 90/768 --> Merged tokens (101, 259) into token 345
# 91/768 --> Merged tokens (100, 261) into token 346
# 92/768 --> Merged tokens (117, 110) into token 347
# 93/768 --> Merged tokens (69, 78) into token 348
# 94/768 --> Merged tokens (107, 256) into token 349
# 95/768 --> Merged tokens (121, 261) into token 350
# 96/768 --> Merged tokens (73, 78) into token 351
# 97/768 --> Merged tokens (63, 271) into token 352
# 98/768 --> Merged tokens (97, 259) into token 353
# 99/768 --> Merged tokens (32, 100) into token 354
# 100/768 --> Merged tokens (102, 97) into token 355
# 101/768 --> Merged tokens (119, 303) into token 356
# 102/768 --> Merged tokens (276, 301) into token 357
# 103/768 --> Merged tokens (83, 267) into token 358
# 104/768 --> Merged tokens (32, 99) into token 359
# 105/768 --> Merged tokens (87, 104) into token 360
# 106/768 --> Merged tokens (257, 310) into token 361
# 107/768 --> Merged tokens (270, 116) into token 362
# 108/768 --> Merged tokens (257, 101) into token 363
# 109/768 --> Merged tokens (99, 101) into token 364
# 110/768 --> Merged tokens (115, 104) into token 365
# 111/768 --> Merged tokens (109, 97) into token 366
# 112/768 --> Merged tokens (32, 112) into token 367
# 113/768 --> Merged tokens (257, 263) into token 368
# 114/768 --> Merged tokens (98, 101) into token 369
# 115/768 --> Merged tokens (46, 32) into token 370
# 116/768 --> Merged tokens (65, 82) into token 371
# 117/768 --> Merged tokens (99, 256) into token 372
# 118/768 --> Merged tokens (291, 32) into token 373
# 119/768 --> Merged tokens (97, 108) into token 374
# 120/768 --> Merged tokens (59, 32) into token 375
# 121/768 --> Merged tokens (115, 261) into token 376
# 122/768 --> Merged tokens (257, 262) into token 377
# 123/768 --> Merged tokens (109, 256) into token 378
# 124/768 --> Merged tokens (115, 256) into token 379
# 125/768 --> Merged tokens (108, 111) into token 380
# 126/768 --> Merged tokens (99, 107) into token 381
# 127/768 --> Merged tokens (119, 104) into token 382
# 128/768 --> Merged tokens (105, 108) into token 383
# 129/768 --> Merged tokens (39, 260) into token 384
# 130/768 --> Merged tokens (73, 339) into token 385
# 131/768 --> Merged tokens (110, 285) into token 386
# 132/768 --> Merged tokens (105, 275) into token 387
# 133/768 --> Merged tokens (101, 275) into token 388
# 134/768 --> Merged tokens (98, 256) into token 389
# 135/768 --> Merged tokens (114, 286) into token 390
# 136/768 --> Merged tokens (32, 116) into token 391
# 137/768 --> Merged tokens (116, 261) into token 392
# 138/768 --> Merged tokens (262, 337) into token 393
# 139/768 --> Merged tokens (101, 10) into token 394
# 140/768 --> Merged tokens (287, 265) into token 395
# 141/768 --> Merged tokens (118, 263) into token 396
# 142/768 --> Merged tokens (99, 292) into token 397
# 143/768 --> Merged tokens (104, 256) into token 398
# 144/768 --> Merged tokens (32, 283) into token 399
# 145/768 --> Merged tokens (32, 73) into token 400
# 146/768 --> Merged tokens (101, 108) into token 401
# 147/768 --> Merged tokens (85, 358) into token 402
# 148/768 --> Merged tokens (111, 108) into token 403
# 149/768 --> Merged tokens (100, 105) into token 404
# 150/768 --> Merged tokens (32, 103) into token 405
# 151/768 --> Merged tokens (97, 265) into token 406
# 152/768 --> Merged tokens (116, 263) into token 407
# 153/768 --> Merged tokens (97, 264) into token 408
# 154/768 --> Merged tokens (32, 281) into token 409
# 155/768 --> Merged tokens (307, 256) into token 410
# 156/768 --> Merged tokens (105, 274) into token 411
# 157/768 --> Merged tokens (108, 256) into token 412
# 158/768 --> Merged tokens (32, 102) into token 413
# 159/768 --> Merged tokens (114, 117) into token 414
# 160/768 --> Merged tokens (105, 102) into token 415
# 161/768 --> Merged tokens (101, 109) into token 416
# 162/768 --> Merged tokens (266, 100) into token 417
# 163/768 --> Merged tokens (84, 269) into token 418
# 164/768 --> Merged tokens (105, 318) into token 419
# 165/768 --> Merged tokens (272, 256) into token 420
# 166/768 --> Merged tokens (117, 112) into token 421
# 167/768 --> Merged tokens (277, 324) into token 422
# 168/768 --> Merged tokens (104, 315) into token 423
# 169/768 --> Merged tokens (101, 100) into token 424
# 170/768 --> Merged tokens (105, 308) into token 425
# 171/768 --> Merged tokens (268, 100) into token 426
# 172/768 --> Merged tokens (105, 294) into token 427
# 173/768 --> Merged tokens (108, 265) into token 428
# 174/768 --> Merged tokens (317, 260) into token 429
# 175/768 --> Merged tokens (85, 67) into token 430
# 176/768 --> Merged tokens (285, 110) into token 431
# 177/768 --> Merged tokens (104, 279) into token 432
# 178/768 --> Merged tokens (351, 71) into token 433
# 179/768 --> Merged tokens (32, 284) into token 434
# 180/768 --> Merged tokens (99, 274) into token 435
# 181/768 --> Merged tokens (110, 101) into token 436
# 182/768 --> Merged tokens (97, 121) into token 437
# 183/768 --> Merged tokens (101, 278) into token 438
# 184/768 --> Merged tokens (114, 292) into token 439
# 185/768 --> Merged tokens (117, 115) into token 440
# 186/768 --> Merged tokens (105, 100) into token 441
# 187/768 --> Merged tokens (262, 110) into token 442
# 188/768 --> Merged tokens (65, 78) into token 443
# 189/768 --> Merged tokens (109, 266) into token 444
# 190/768 --> Merged tokens (97, 103) into token 445
# 191/768 --> Merged tokens (69, 82) into token 446
# 192/768 --> Merged tokens (79, 82) into token 447
# 193/768 --> Merged tokens (101, 258) into token 448
# 194/768 --> Merged tokens (114, 280) into token 449
# 195/768 --> Merged tokens (305, 108) into token 450
# 196/768 --> Merged tokens (290, 279) into token 451
# 197/768 --> Merged tokens (101, 277) into token 452
# 198/768 --> Merged tokens (101, 116) into token 453
# 199/768 --> Merged tokens (99, 97) into token 454
# 200/768 --> Merged tokens (32, 264) into token 455
# 201/768 --> Merged tokens (115, 276) into token 456
# 202/768 --> Merged tokens (33, 10) into token 457
# 203/768 --> Merged tokens (69, 84) into token 458
# 204/768 --> Merged tokens (84, 334) into token 459
# 205/768 --> Merged tokens (112, 111) into token 460
# 206/768 --> Merged tokens (113, 117) into token 461
# 207/768 --> Merged tokens (257, 265) into token 462
# 208/768 --> Merged tokens (33, 271) into token 463
# 209/768 --> Merged tokens (109, 268) into token 464
# 210/768 --> Merged tokens (117, 108) into token 465
# 211/768 --> Merged tokens (110, 269) into token 466
# 212/768 --> Merged tokens (97, 109) into token 467
# 213/768 --> Merged tokens (273, 101) into token 468
# 214/768 --> Merged tokens (65, 267) into token 469
# 215/768 --> Merged tokens (118, 270) into token 470
# 216/768 --> Merged tokens (98, 265) into token 471
# 217/768 --> Merged tokens (115, 10) into token 472
# 218/768 --> Merged tokens (75, 433) into token 473
# 219/768 --> Merged tokens (115, 112) into token 474
# 220/768 --> Merged tokens (290, 315) into token 475
# 221/768 --> Merged tokens (257, 279) into token 476
# 222/768 --> Merged tokens (273, 279) into token 477
# 223/768 --> Merged tokens (104, 263) into token 478
# 224/768 --> Merged tokens (273, 310) into token 479
# 225/768 --> Merged tokens (111, 257) into token 480
# 226/768 --> Merged tokens (63, 10) into token 481
# 227/768 --> Merged tokens (274, 103) into token 482
# 228/768 --> Merged tokens (66, 336) into token 483
# 229/768 --> Merged tokens (280, 258) into token 484
# 230/768 --> Merged tokens (111, 261) into token 485
# 231/768 --> Merged tokens (98, 336) into token 486
# 232/768 --> Merged tokens (32, 289) into token 487
# 233/768 --> Merged tokens (70, 268) into token 488
# 234/768 --> Merged tokens (115, 117) into token 489
# 235/768 --> Merged tokens (288, 303) into token 490
# 236/768 --> Merged tokens (117, 116) into token 491
# 237/768 --> Merged tokens (274, 256) into token 492
# 238/768 --> Merged tokens (97, 275) into token 493
# 239/768 --> Merged tokens (73, 67) into token 494
# 240/768 --> Merged tokens (270, 100) into token 495
# 241/768 --> Merged tokens (79, 76) into token 496
# 242/768 --> Merged tokens (100, 269) into token 497
# 243/768 --> Merged tokens (73, 288) into token 498
# 244/768 --> Merged tokens (292, 256) into token 499
# 245/768 --> Merged tokens (107, 386) into token 500
# 246/768 --> Merged tokens (115, 277) into token 501
# 247/768 --> Merged tokens (115, 299) into token 502
# 248/768 --> Merged tokens (261, 284) into token 503
# 249/768 --> Merged tokens (99, 116) into token 504
# 250/768 --> Merged tokens (117, 259) into token 505
# 251/768 --> Merged tokens (280, 259) into token 506
# 252/768 --> Merged tokens (450, 102) into token 507
# 253/768 --> Merged tokens (282, 116) into token 508
# 254/768 --> Merged tokens (97, 349) into token 509
# 255/768 --> Merged tokens (69, 76) into token 510
# 256/768 --> Merged tokens (108, 286) into token 511
# 257/768 --> Merged tokens (107, 291) into token 512
# 258/768 --> Merged tokens (288, 104) into token 513
# 259/768 --> Merged tokens (272, 100) into token 514
# 260/768 --> Merged tokens (119, 268) into token 515
# 261/768 --> Merged tokens (111, 112) into token 516
# 262/768 --> Merged tokens (297, 256) into token 517
# 263/768 --> Merged tokens (97, 100) into token 518
# 264/768 --> Merged tokens (73, 402) into token 519
# 265/768 --> Merged tokens (473, 32) into token 520
# 266/768 --> Merged tokens (371, 68) into token 521
# 267/768 --> Merged tokens (273, 262) into token 522
# 268/768 --> Merged tokens (115, 269) into token 523
# 269/768 --> Merged tokens (32, 332) into token 524
# 270/768 --> Merged tokens (104, 314) into token 525
# 271/768 --> Merged tokens (270, 258) into token 526
# 272/768 --> Merged tokens (109, 111) into token 527
# 273/768 --> Merged tokens (280, 116) into token 528
# 274/768 --> Merged tokens (116, 111) into token 529
# 275/768 --> Merged tokens (45, 45) into token 530
# 276/768 --> Merged tokens (99, 105) into token 531
# 277/768 --> Merged tokens (83, 84) into token 532
# 278/768 --> Merged tokens (77, 265) into token 533
# 279/768 --> Merged tokens (281, 32) into token 534
# 280/768 --> Merged tokens (270, 32) into token 535
# 281/768 --> Merged tokens (39, 116) into token 536
# 282/768 --> Merged tokens (262, 259) into token 537
# 283/768 --> Merged tokens (119, 256) into token 538
# 284/768 --> Merged tokens (100, 10) into token 539
# 285/768 --> Merged tokens (108, 317) into token 540
# 286/768 --> Merged tokens (58, 32) into token 541
# 287/768 --> Merged tokens (69, 267) into token 542
# 288/768 --> Merged tokens (100, 101) into token 543
# 289/768 --> Merged tokens (33, 32) into token 544
# 290/768 --> Merged tokens (73, 39) into token 545
# 291/768 --> Merged tokens (293, 109) into token 546
# 292/768 --> Merged tokens (273, 265) into token 547
# 293/768 --> Merged tokens (79, 78) into token 548
# 294/768 --> Merged tokens (290, 256) into token 549
# 295/768 --> Merged tokens (264, 32) into token 550
# 296/768 --> Merged tokens (114, 266) into token 551
# 297/768 --> Merged tokens (115, 97) into token 552
# 298/768 --> Merged tokens (100, 286) into token 553
# 299/768 --> Merged tokens (264, 107) into token 554
# 300/768 --> Merged tokens (266, 32) into token 555
# 301/768 --> Merged tokens (263, 101) into token 556
# 302/768 --> Merged tokens (117, 294) into token 557
# 303/768 --> Merged tokens (282, 276) into token 558
# 304/768 --> Merged tokens (320, 104) into token 559
# 305/768 --> Merged tokens (115, 274) into token 560
# 306/768 --> Merged tokens (105, 301) into token 561
# 307/768 --> Merged tokens (102, 439) into token 562
# 308/768 --> Merged tokens (103, 429) into token 563
# 309/768 --> Merged tokens (117, 311) into token 564
# 310/768 --> Merged tokens (115, 119) into token 565
# 311/768 --> Merged tokens (278, 67) into token 566
# 312/768 --> Merged tokens (97, 98) into token 567
# 313/768 --> Merged tokens (108, 426) into token 568
# 314/768 --> Merged tokens (65, 259) into token 569
# 315/768 --> Merged tokens (276, 257) into token 570
# 316/768 --> Merged tokens (278, 80) into token 571
# 317/768 --> Merged tokens (87, 334) into token 572
# 318/768 --> Merged tokens (97, 32) into token 573
# 319/768 --> Merged tokens (286, 107) into token 574
# 320/768 --> Merged tokens (114, 285) into token 575
# 321/768 --> Merged tokens (116, 10) into token 576
# 322/768 --> Merged tokens (264, 256) into token 577
# 323/768 --> Merged tokens (262, 108) into token 578
# 324/768 --> Merged tokens (105, 103) into token 579
# 325/768 --> Merged tokens (100, 263) into token 580
# 326/768 --> Merged tokens (89, 262) into token 581
# 327/768 --> Merged tokens (112, 263) into token 582
# 328/768 --> Merged tokens (380, 118) into token 583
# 329/768 --> Merged tokens (278, 76) into token 584
# 330/768 --> Merged tokens (112, 114) into token 585
# 331/768 --> Merged tokens (306, 349) into token 586
# 332/768 --> Merged tokens (521, 400) into token 587
# 333/768 --> Merged tokens (72, 97) into token 588
# 334/768 --> Merged tokens (329, 324) into token 589
# 335/768 --> Merged tokens (82, 79) into token 590
# 336/768 --> Merged tokens (256, 283) into token 591
# 337/768 --> Merged tokens (280, 115) into token 592
# 338/768 --> Merged tokens (84, 385) into token 593
# 339/768 --> Merged tokens (109, 101) into token 594
# 340/768 --> Merged tokens (105, 99) into token 595
# 341/768 --> Merged tokens (262, 318) into token 596
# 342/768 --> Merged tokens (282, 104) into token 597
# 343/768 --> Merged tokens (421, 274) into token 598
# 344/768 --> Merged tokens (73, 267) into token 599
# 345/768 --> Merged tokens (262, 258) into token 600
# 346/768 --> Merged tokens (268, 32) into token 601
# 347/768 --> Merged tokens (121, 10) into token 602
# 348/768 --> Merged tokens (458, 267) into token 603
# 349/768 --> Merged tokens (119, 353) into token 604
# 350/768 --> Merged tokens (65, 85) into token 605
# 351/768 --> Merged tokens (112, 343) into token 606
# 352/768 --> Merged tokens (99, 266) into token 607
# 353/768 --> Merged tokens (119, 334) into token 608
# 354/768 --> Merged tokens (263, 118) into token 609
# 355/768 --> Merged tokens (321, 258) into token 610
# 356/768 --> Merged tokens (97, 350) into token 611
# 357/768 --> Merged tokens (89, 32) into token 612
# 358/768 --> Merged tokens (266, 116) into token 613
# 359/768 --> Merged tokens (105, 260) into token 614
# 360/768 --> Merged tokens (313, 357) into token 615
# 361/768 --> Merged tokens (69, 32) into token 616
# 362/768 --> Merged tokens (323, 32) into token 617
# 363/768 --> Merged tokens (297, 336) into token 618
# 364/768 --> Merged tokens (300, 32) into token 619
# 365/768 --> Merged tokens (297, 101) into token 620
# 366/768 --> Merged tokens (104, 286) into token 621
# 367/768 --> Merged tokens (306, 102) into token 622
# 368/768 --> Merged tokens (97, 115) into token 623
# 369/768 --> Merged tokens (119, 388) into token 624
# 370/768 --> Merged tokens (111, 337) into token 625
# 371/768 --> Merged tokens (277, 360) into token 626
# 372/768 --> Merged tokens (101, 121) into token 627
# 373/768 --> Merged tokens (73, 110) into token 628
# 374/768 --> Merged tokens (299, 311) into token 629
# 375/768 --> Merged tokens (117, 109) into token 630
# 376/768 --> Merged tokens (63, 32) into token 631
# 377/768 --> Merged tokens (266, 103) into token 632
# 378/768 --> Merged tokens (73, 546) into token 633
# 379/768 --> Merged tokens (32, 338) into token 634
# 380/768 --> Merged tokens (105, 296) into token 635
# 381/768 --> Merged tokens (363, 109) into token 636
# 382/768 --> Merged tokens (270, 260) into token 637
# 383/768 --> Merged tokens (75, 267) into token 638
# 384/768 --> Merged tokens (276, 116) into token 639
# 385/768 --> Merged tokens (73, 102) into token 640
# 386/768 --> Merged tokens (332, 32) into token 641
# 387/768 --> Merged tokens (494, 72) into token 642
# 388/768 --> Merged tokens (119, 272) into token 643
# 389/768 --> Merged tokens (82, 642) into token 644
# 390/768 --> Merged tokens (326, 112) into token 645
# 391/768 --> Merged tokens (68, 85) into token 646
# 392/768 --> Merged tokens (646, 75) into token 647
# 393/768 --> Merged tokens (102, 465) into token 648
# 394/768 --> Merged tokens (377, 32) into token 649
# 395/768 --> Merged tokens (647, 616) into token 650
# 396/768 --> Merged tokens (115, 111) into token 651
# 397/768 --> Merged tokens (111, 100) into token 652
# 398/768 --> Merged tokens (293, 259) into token 653
# 399/768 --> Merged tokens (116, 116) into token 654
# 400/768 --> Merged tokens (300, 256) into token 655
# 401/768 --> Merged tokens (116, 414) into token 656
# 402/768 --> Merged tokens (105, 381) into token 657
# 403/768 --> Merged tokens (276, 260) into token 658
# 404/768 --> Merged tokens (87, 303) into token 659
# 405/768 --> Merged tokens (98, 412) into token 660
# 406/768 --> Merged tokens (419, 116) into token 661
# 407/768 --> Merged tokens (112, 112) into token 662
# 408/768 --> Merged tokens (348, 593) into token 663
# 409/768 --> Merged tokens (116, 315) into token 664
# 410/768 --> Merged tokens (446, 267) into token 665
# 411/768 --> Merged tokens (264, 100) into token 666
# 412/768 --> Merged tokens (464, 256) into token 667
# 413/768 --> Merged tokens (73, 282) into token 668
# 414/768 --> Merged tokens (363, 265) into token 669
# 415/768 --> Merged tokens (280, 261) into token 670
# 416/768 --> Merged tokens (278, 66) into token 671
# 417/768 --> Merged tokens (456, 275) into token 672
# 418/768 --> Merged tokens (280, 256) into token 673
# 419/768 --> Merged tokens (278, 520) into token 674
# 420/768 --> Merged tokens (278, 83) into token 675
# 421/768 --> Merged tokens (119, 425) into token 676
# 422/768 --> Merged tokens (355, 368) into token 677
# 423/768 --> Merged tokens (101, 120) into token 678
# 424/768 --> Merged tokens (278, 71) into token 679
# 425/768 --> Merged tokens (100, 111) into token 680
# 426/768 --> Merged tokens (375, 284) into token 681
# 427/768 --> Merged tokens (89, 267) into token 682
# 428/768 --> Merged tokens (257, 270) into token 683
# 429/768 --> Merged tokens (290, 263) into token 684
# 430/768 --> Merged tokens (119, 344) into token 685
# 431/768 --> Merged tokens (293, 275) into token 686
# 432/768 --> Merged tokens (79, 261) into token 687
# 433/768 --> Merged tokens (351, 67) into token 688
# 434/768 --> Merged tokens (285, 32) into token 689
# 435/768 --> Merged tokens (287, 256) into token 690
# 436/768 --> Merged tokens (101, 325) into token 691
# 437/768 --> Merged tokens (98, 108) into token 692
# 438/768 --> Merged tokens (72, 256) into token 693
# 439/768 --> Merged tokens (108, 268) into token 694
# 440/768 --> Merged tokens (278, 77) into token 695
# 441/768 --> Merged tokens (111, 379) into token 696
# 442/768 --> Merged tokens (579, 110) into token 697
# 443/768 --> Merged tokens (98, 343) into token 698
# 444/768 --> Merged tokens (283, 295) into token 699
# 445/768 --> Merged tokens (114, 265) into token 700
# 446/768 --> Merged tokens (117, 318) into token 701
# 447/768 --> Merged tokens (79, 102) into token 702
# 448/768 --> Merged tokens (287, 101) into token 703
# 449/768 --> Merged tokens (396, 265) into token 704
# 450/768 --> Merged tokens (292, 101) into token 705
# 451/768 --> Merged tokens (264, 304) into token 706
# 452/768 --> Merged tokens (270, 364) into token 707
# 453/768 --> Merged tokens (10, 418) into token 708
# 454/768 --> Merged tokens (101, 112) into token 709
# 455/768 --> Merged tokens (65, 66) into token 710
# 456/768 --> Merged tokens (119, 387) into token 711
# 457/768 --> Merged tokens (102, 335) into token 712
# 458/768 --> Merged tokens (553, 257) into token 713
# 459/768 --> Merged tokens (270, 372) into token 714
# 460/768 --> Merged tokens (100, 277) into token 715
# 461/768 --> Merged tokens (293, 32) into token 716
# 462/768 --> Merged tokens (419, 258) into token 717
# 463/768 --> Merged tokens (112, 272) into token 718
# 464/768 --> Merged tokens (266, 265) into token 719
# 465/768 --> Merged tokens (540, 107) into token 720
# 466/768 --> Merged tokens (97, 119) into token 721
# 467/768 --> Merged tokens (366, 349) into token 722
# 468/768 --> Merged tokens (545, 308) into token 723
# 469/768 --> Merged tokens (76, 79) into token 724
# 470/768 --> Merged tokens (644, 587) into token 725
# 471/768 --> Merged tokens (70, 629) into token 726
# 472/768 --> Merged tokens (69, 532) into token 727
# 473/768 --> Merged tokens (257, 322) into token 728
# 474/768 --> Merged tokens (436, 119) into token 729
# 475/768 --> Merged tokens (363, 299) into token 730
# 476/768 --> Merged tokens (288, 334) into token 731
# 477/768 --> Merged tokens (430, 72) into token 732
# 478/768 --> Merged tokens (105, 118) into token 733
# 479/768 --> Merged tokens (119, 393) into token 734
# 480/768 --> Merged tokens (99, 302) into token 735
# 481/768 --> Merged tokens (259, 284) into token 736
# 482/768 --> Merged tokens (103, 330) into token 737
# 483/768 --> Merged tokens (103, 101) into token 738
# 484/768 --> Merged tokens (272, 109) into token 739
# 485/768 --> Merged tokens (724, 430) into token 740
# 486/768 --> Merged tokens (740, 727) into token 741
# 487/768 --> Merged tokens (741, 665) into token 742
# 488/768 --> Merged tokens (355, 299) into token 743
# 489/768 --> Merged tokens (118, 111) into token 744
# 490/768 --> Merged tokens (121, 448) into token 745
# 491/768 --> Merged tokens (114, 431) into token 746
# 492/768 --> Merged tokens (69, 348) into token 747
# 493/768 --> Merged tokens (363, 256) into token 748
# 494/768 --> Merged tokens (468, 299) into token 749
# 495/768 --> Merged tokens (382, 427) into token 750
# 496/768 --> Merged tokens (282, 269) into token 751
# 497/768 --> Merged tokens (307, 279) into token 752
# 498/768 --> Merged tokens (307, 262) into token 753
# 499/768 --> Merged tokens (76, 73) into token 754
# 500/768 --> Merged tokens (333, 256) into token 755
# 501/768 --> Merged tokens (288, 256) into token 756
# 502/768 --> Merged tokens (366, 100) into token 757
# 503/768 --> Merged tokens (121, 507) into token 758
# 504/768 --> Merged tokens (365, 256) into token 759
# 505/768 --> Merged tokens (101, 102) into token 760
# 506/768 --> Merged tokens (296, 263) into token 761
# 507/768 --> Merged tokens (274, 323) into token 762
# 508/768 --> Merged tokens (101, 118) into token 763
# 509/768 --> Merged tokens (261, 328) into token 764
# 510/768 --> Merged tokens (306, 118) into token 765
# 511/768 --> Merged tokens (101, 308) into token 766
# 512/768 --> Merged tokens (380, 301) into token 767
# 513/768 --> Merged tokens (326, 258) into token 768
# 514/768 --> Merged tokens (101, 504) into token 769
# 515/768 --> Merged tokens (264, 260) into token 770
# 516/768 --> Merged tokens (273, 416) into token 771
# 517/768 --> Merged tokens (289, 304) into token 772
# 518/768 --> Merged tokens (257, 266) into token 773
# 519/768 --> Merged tokens (404, 260) into token 774
# 520/768 --> Merged tokens (81, 85) into token 775
# 521/768 --> Merged tokens (775, 747) into token 776
# 522/768 --> Merged tokens (86, 688) into token 777
# 523/768 --> Merged tokens (777, 663) into token 778
# 524/768 --> Merged tokens (456, 308) into token 779
# 525/768 --> Merged tokens (67, 292) into token 780
# 526/768 --> Merged tokens (79, 70) into token 781
# 527/768 --> Merged tokens (781, 32) into token 782
# 528/768 --> Merged tokens (289, 102) into token 783
# 529/768 --> Merged tokens (298, 116) into token 784
# 530/768 --> Merged tokens (333, 110) into token 785
# 531/768 --> Merged tokens (77, 272) into token 786
# 532/768 --> Merged tokens (282, 112) into token 787
# 533/768 --> Merged tokens (326, 100) into token 788
# 534/768 --> Merged tokens (257, 291) into token 789
# 535/768 --> Merged tokens (356, 32) into token 790
# 536/768 --> Merged tokens (32, 300) into token 791
# 537/768 --> Merged tokens (65, 77) into token 792
# 538/768 --> Merged tokens (118, 105) into token 793
# 539/768 --> Merged tokens (101, 270) into token 794
# 540/768 --> Merged tokens (72, 348) into token 795
# 541/768 --> Merged tokens (112, 341) into token 796
# 542/768 --> Merged tokens (111, 39) into token 797
# 543/768 --> Merged tokens (97, 107) into token 798
# 544/768 --> Merged tokens (445, 408) into token 799
# 545/768 --> Merged tokens (502, 261) into token 800
# 546/768 --> Merged tokens (117, 379) into token 801
# 547/768 --> Merged tokens (318, 116) into token 802
# 548/768 --> Merged tokens (103, 561) into token 803
# 549/768 --> Merged tokens (10, 324) into token 804
# 550/768 --> Merged tokens (121, 277) into token 805
# 551/768 --> Merged tokens (103, 111) into token 806
# 552/768 --> Merged tokens (71, 111) into token 807
# 553/768 --> Merged tokens (97, 308) into token 808
# 554/768 --> Merged tokens (397, 256) into token 809
# 555/768 --> Merged tokens (83, 269) into token 810
# 556/768 --> Merged tokens (795, 82) into token 811
# 557/768 --> Merged tokens (811, 612) into token 812
# 558/768 --> Merged tokens (101, 99) into token 813
# 559/768 --> Merged tokens (109, 272) into token 814
# 560/768 --> Merged tokens (536, 279) into token 815
# 561/768 --> Merged tokens (69, 83) into token 816
# 562/768 --> Merged tokens (305, 260) into token 817
# 563/768 --> Merged tokens (318, 258) into token 818
# 564/768 --> Merged tokens (267, 65) into token 819
# 565/768 --> Merged tokens (268, 256) into token 820
# 566/768 --> Merged tokens (290, 314) into token 821
# 567/768 --> Merged tokens (116, 509) into token 822
# 568/768 --> Merged tokens (103, 256) into token 823
# 569/768 --> Merged tokens (362, 321) into token 824
# 570/768 --> Merged tokens (100, 320) into token 825
# 571/768 --> Merged tokens (447, 73) into token 826
# 572/768 --> Merged tokens (110, 103) into token 827
# 573/768 --> Merged tokens (262, 115) into token 828
# 574/768 --> Merged tokens (111, 368) into token 829
# 575/768 --> Merged tokens (98, 263) into token 830
# 576/768 --> Merged tokens (104, 322) into token 831
# 577/768 --> Merged tokens (100, 117) into token 832
# 578/768 --> Merged tokens (650, 778) into token 833
# 579/768 --> Merged tokens (32, 279) into token 834
# 580/768 --> Merged tokens (776, 32) into token 835
# 581/768 --> Merged tokens (106, 111) into token 836
# 582/768 --> Merged tokens (69, 358) into token 837
# 583/768 --> Merged tokens (73, 259) into token 838
# 584/768 --> Merged tokens (285, 263) into token 839
# 585/768 --> Merged tokens (101, 39) into token 840
# 586/768 --> Merged tokens (274, 101) into token 841
# 587/768 --> Merged tokens (109, 270) into token 842
# 588/768 --> Merged tokens (89, 447) into token 843
# 589/768 --> Merged tokens (843, 638) into token 844
# 590/768 --> Merged tokens (99, 442) into token 845
# 591/768 --> Merged tokens (97, 112) into token 846
# 592/768 --> Merged tokens (117, 296) into token 847
# 593/768 --> Merged tokens (319, 256) into token 848
# 594/768 --> Merged tokens (272, 258) into token 849
# 595/768 --> Merged tokens (100, 280) into token 850
# 596/768 --> Merged tokens (87, 256) into token 851
# 597/768 --> Merged tokens (319, 411) into token 852
# 598/768 --> Merged tokens (79, 114) into token 853
# 599/768 --> Merged tokens (474, 574) into token 854
# 600/768 --> Merged tokens (32, 342) into token 855
# 601/768 --> Merged tokens (102, 105) into token 856
# 602/768 --> Merged tokens (351, 519) into token 857
# 603/768 --> Merged tokens (32, 327) into token 858
# 604/768 --> Merged tokens (112, 330) into token 859
# 605/768 --> Merged tokens (39, 100) into token 860
# 606/768 --> Merged tokens (116, 119) into token 861
# 607/768 --> Merged tokens (267, 78) into token 862
# 608/768 --> Merged tokens (359, 292) into token 863
# 609/768 --> Merged tokens (105, 122) into token 864
# 610/768 --> Merged tokens (273, 266) into token 865
# 611/768 --> Merged tokens (366, 265) into token 866
# 612/768 --> Merged tokens (268, 110) into token 867
# 613/768 --> Merged tokens (281, 261) into token 868
# 614/768 --> Merged tokens (280, 10) into token 869
# 615/768 --> Merged tokens (97, 99) into token 870
# 616/768 --> Merged tokens (39, 84) into token 871
# 617/768 --> Merged tokens (73, 258) into token 872
# 618/768 --> Merged tokens (109, 557) into token 873
# 619/768 --> Merged tokens (69, 68) into token 874
# 620/768 --> Merged tokens (874, 87) into token 875
# 621/768 --> Merged tokens (108, 417) into token 876
# 622/768 --> Merged tokens (97, 701) into token 877
# 623/768 --> Merged tokens (44, 530) into token 878
# 624/768 --> Merged tokens (111, 311) into token 879
# 625/768 --> Merged tokens (390, 258) into token 880
# 626/768 --> Merged tokens (365, 393) into token 881
# 627/768 --> Merged tokens (360, 427) into token 882
# 628/768 --> Merged tokens (84, 72) into token 883
# 629/768 --> Merged tokens (317, 107) into token 884
# 630/768 --> Merged tokens (103, 408) into token 885
# 631/768 --> Merged tokens (382, 270) into token 886
# 632/768 --> Merged tokens (85, 77) into token 887
# 633/768 --> Merged tokens (360, 350) into token 888
# 634/768 --> Merged tokens (98, 111) into token 889
# 635/768 --> Merged tokens (65, 76) into token 890
# 636/768 --> Merged tokens (116, 322) into token 891
# 637/768 --> Merged tokens (73, 287) into token 892
# 638/768 --> Merged tokens (527, 311) into token 893
# 639/768 --> Merged tokens (108, 482) into token 894
# 640/768 --> Merged tokens (102, 314) into token 895
# 641/768 --> Merged tokens (290, 286) into token 896
# 642/768 --> Merged tokens (442, 100) into token 897
# 643/768 --> Merged tokens (32, 313) into token 898
# 644/768 --> Merged tokens (73, 83) into token 899
# 645/768 --> Merged tokens (116, 259) into token 900
# 646/768 --> Merged tokens (115, 499) into token 901
# 647/768 --> Merged tokens (510, 76) into token 902
# 648/768 --> Merged tokens (329, 488) into token 903
# 649/768 --> Merged tokens (435, 260) into token 904
# 650/768 --> Merged tokens (116, 340) into token 905
# 651/768 --> Merged tokens (266, 258) into token 906
# 652/768 --> Merged tokens (69, 100) into token 907
# 653/768 --> Merged tokens (257, 554) into token 908
# 654/768 --> Merged tokens (298, 660) into token 909
# 655/768 --> Merged tokens (268, 260) into token 910
# 656/768 --> Merged tokens (97, 381) into token 911
# 657/768 --> Merged tokens (79, 77) into token 912
# 658/768 --> Merged tokens (108, 506) into token 913
# 659/768 --> Merged tokens (277, 418) into token 914
# 660/768 --> Merged tokens (77, 69) into token 915
# 661/768 --> Merged tokens (39, 311) into token 916
# 662/768 --> Merged tokens (276, 392) into token 917
# 663/768 --> Merged tokens (103, 269) into token 918
# 664/768 --> Merged tokens (277, 459) into token 919
# 665/768 --> Merged tokens (272, 101) into token 920
# 666/768 --> Merged tokens (104, 285) into token 921
# 667/768 --> Merged tokens (65, 80) into token 922
# 668/768 --> Merged tokens (590, 915) into token 923
# 669/768 --> Merged tokens (923, 339) into token 924
# 670/768 --> Merged tokens (348, 348) into token 925
# 671/768 --> Merged tokens (925, 519) into token 926
# 672/768 --> Merged tokens (303, 263) into token 927
# 673/768 --> Merged tokens (287, 266) into token 928
# 674/768 --> Merged tokens (302, 284) into token 929
# 675/768 --> Merged tokens (104, 344) into token 930
# 676/768 --> Merged tokens (66, 265) into token 931
# 677/768 --> Merged tokens (109, 564) into token 932
# 678/768 --> Merged tokens (112, 449) into token 933
# 679/768 --> Merged tokens (97, 102) into token 934
# 680/768 --> Merged tokens (309, 109) into token 935
# 681/768 --> Merged tokens (458, 82) into token 936
# 682/768 --> Merged tokens (936, 732) into token 937
# 683/768 --> Merged tokens (937, 385) into token 938
# 684/768 --> Merged tokens (309, 112) into token 939
# 685/768 --> Merged tokens (259, 283) into token 940
# 686/768 --> Merged tokens (297, 265) into token 941
# 687/768 --> Merged tokens (116, 388) into token 942
# 688/768 --> Merged tokens (105, 112) into token 943
# 689/768 --> Merged tokens (111, 258) into token 944
# 690/768 --> Merged tokens (72, 285) into token 945
# 691/768 --> Merged tokens (108, 121) into token 946
# 692/768 --> Merged tokens (109, 362) into token 947
# 693/768 --> Merged tokens (259, 289) into token 948
# 694/768 --> Merged tokens (272, 260) into token 949
# 695/768 --> Merged tokens (807, 260) into token 950
# 696/768 --> Merged tokens (101, 904) into token 951
# 697/768 --> Merged tokens (103, 117) into token 952
# 698/768 --> Merged tokens (10, 65) into token 953
# 699/768 --> Merged tokens (100, 265) into token 954
# 700/768 --> Merged tokens (694, 346) into token 955
# 701/768 --> Merged tokens (309, 116) into token 956
# 702/768 --> Merged tokens (780, 302) into token 957
# 703/768 --> Merged tokens (10, 410) into token 958
# 704/768 --> Merged tokens (264, 372) into token 959
# 705/768 --> Merged tokens (274, 32) into token 960
# 706/768 --> Merged tokens (82, 705) into token 961
# 707/768 --> Merged tokens (268, 116) into token 962
# 708/768 --> Merged tokens (548, 84) into token 963
# 709/768 --> Merged tokens (111, 275) into token 964
# 710/768 --> Merged tokens (266, 346) into token 965
# 711/768 --> Merged tokens (101, 331) into token 966
# 712/768 --> Merged tokens (267, 307) into token 967
# 713/768 --> Merged tokens (413, 439) into token 968
# 714/768 --> Merged tokens (267, 83) into token 969
# 715/768 --> Merged tokens (712, 495) into token 970
# 716/768 --> Merged tokens (826, 496) into token 971
# 717/768 --> Merged tokens (971, 443) into token 972
# 718/768 --> Merged tokens (293, 258) into token 973
# 719/768 --> Merged tokens (607, 327) into token 974
# 720/768 --> Merged tokens (558, 308) into token 975
# 721/768 --> Merged tokens (403, 100) into token 976
# 722/768 --> Merged tokens (972, 402) into token 977
# 723/768 --> Merged tokens (101, 352) into token 978
# 724/768 --> Merged tokens (114, 482) into token 979
# 725/768 --> Merged tokens (115, 99) into token 980
# 726/768 --> Merged tokens (344, 279) into token 981
# 727/768 --> Merged tokens (100, 437) into token 982
# 728/768 --> Merged tokens (674, 725) into token 983
# 729/768 --> Merged tokens (66, 101) into token 984
# 730/768 --> Merged tokens (257, 319) into token 985
# 731/768 --> Merged tokens (114, 121) into token 986
# 732/768 --> Merged tokens (112, 101) into token 987
# 733/768 --> Merged tokens (286, 108) into token 988
# 734/768 --> Merged tokens (115, 115) into token 989
# 735/768 --> Merged tokens (110, 97) into token 990
# 736/768 --> Merged tokens (461, 794) into token 991
# 737/768 --> Merged tokens (82, 427) into token 992
# 738/768 --> Merged tokens (119, 657) into token 993
# 739/768 --> Merged tokens (278, 726) into token 994
# 740/768 --> Merged tokens (110, 506) into token 995
# 741/768 --> Merged tokens (114, 270) into token 996
# 742/768 --> Merged tokens (319, 294) into token 997
# 743/768 --> Merged tokens (333, 305) into token 998
# 744/768 --> Merged tokens (316, 864) into token 999
# 745/768 --> Merged tokens (999, 270) into token 1000
# 746/768 --> Merged tokens (529, 269) into token 1001
# 747/768 --> Merged tokens (115, 406) into token 1002
# 748/768 --> Merged tokens (32, 276) into token 1003
# 749/768 --> Merged tokens (442, 260) into token 1004
# 750/768 --> Merged tokens (351, 469) into token 1005
# 751/768 --> Merged tokens (259, 338) into token 1006
# 752/768 --> Merged tokens (114, 596) into token 1007
# 753/768 --> Merged tokens (282, 398) into token 1008
# 754/768 --> Merged tokens (290, 322) into token 1009
# 755/768 --> Merged tokens (288, 425) into token 1010
# 756/768 --> Merged tokens (98, 314) into token 1011
# 757/768 --> Merged tokens (277, 83) into token 1012
# 758/768 --> Merged tokens (359, 274) into token 1013
# 759/768 --> Merged tokens (105, 111) into token 1014
# 760/768 --> Merged tokens (257, 326) into token 1015
# 761/768 --> Merged tokens (73, 599) into token 1016
# 762/768 --> Merged tokens (306, 101) into token 1017
# 763/768 --> Merged tokens (320, 256) into token 1018
# 764/768 --> Merged tokens (109, 274) into token 1019
# 765/768 --> Merged tokens (468, 265) into token 1020
# 766/768 --> Merged tokens (305, 256) into token 1021
# 767/768 --> Merged tokens (267, 410) into token 1022
# 768/768 --> Merged tokens (97, 296) into token 1023

# %%
# Check if the state of the tokenizer should be saved
if save_state:
    # Save the state of the tokenizer
    tokenizer.save_state(output_path)

# %% [markdown]
# ### Evaluation

# %%
# Encoding the text
encoded_text = tokenizer.encode(validation_text)

# Decoding the text
decoded_text = tokenizer.decode(encoded_text)

# Print the original text
print(f"Original text")
print("-------------")
print(validation_text)

# Print the encoded text
print("\nEncoded text")
print("------------")
print(encoded_text)

# Print the decoded text
print("\nDecoded text")
print("------------")
print(decoded_text)
# Out:
# Original text
# -------------
#  sleep. What is it thou didst say?
# This is a strange repose, to be asleep
# With eyes wide open; standing, speaking, moving,
# And yet so fast asleep.
#
# ANTONIO:
# Noble Sebastian,
# Thou let'st thy fortune sleep--die, rather; wink'st
# Whiles thou art waking.
#
#
# Encoded text
# ------------
# [282, 321, 709, 46, 32, 87, 639, 32, 320, 32, 316, 522, 354, 441, 296, 282, 437, 481, 307, 320, 32, 320, 293, 508, 551, 738, 32, 309, 460, 305, 44, 391, 111, 620, 293, 115, 321, 709, 10, 659, 32, 627, 280, 288, 441, 101, 32, 516, 270, 59, 508, 417, 291, 44, 787, 286, 512, 44, 287, 111, 118, 291, 277, 312, 100, 32, 121, 453, 282, 111, 32, 355, 296, 293, 115, 321, 709, 278, 443, 84, 548, 73, 79, 267, 78, 111, 98, 321, 32, 83, 101, 98, 1023, 105, 266, 277, 753, 32, 321, 116, 39, 115, 116, 273, 121, 791, 116, 347, 101, 282, 321, 709, 530, 404, 101, 44, 32, 330, 368, 59, 288, 554, 39, 115, 116, 10, 360, 383, 280, 522, 32, 272, 116, 288, 97, 512, 331]
#
# Decoded text
# ------------
#  sleep. What is it thou didst say?
# This is a strange repose, to be asleep
# With eyes wide open; standing, speaking, moving,
# And yet so fast asleep.
#
# ANTONIO:
# Noble Sebastian,
# Thou let'st thy fortune sleep--die, rather; wink'st
# Whiles thou art waking.
