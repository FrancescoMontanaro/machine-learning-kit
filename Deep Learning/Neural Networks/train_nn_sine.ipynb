# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Import the module from the custom library
from src import utils
from src import layers
from src import metrics
from src import callbacks
from src import optimizers
from src import activations
from src import loss_functions
from src import FeedForward

# %% [markdown]
# ### Constants and Hyperparameters

# %%
n_samples = 1000 # Number of samples to generate
train_test_split_pct = 0.2 # Percentage of samples to use for testing
train_valid_split = 0.2 # Percentage of samples to use for validation
learning_rate = 2e-04 # Learning rate for the optimizer
batch_size = 32 # Number of samples to use for each batch
epochs = 300 # Number of epochs to train the model
seed = 1234 # Seed for reproducibility
data_noise = 0.15 # Noise to add to the data

# %%
# Set the seed for reproducibility
np.random.seed(seed)

# %% [markdown]
# ### Data loading

# %%
def generate_sine_dataset(n_samples: int, noise: float = 0.0) -> tuple[np.ndarray, np.ndarray]:
    """
    Method to generate a dataset of samples and targets of a sine function
    
    Parameters: 
    - n_samples (int): Number of samples to generate
    - noise float: Standard deviation of the Gaussian noise. Default is 0 (no noise)
    
    Returns:
    - tuple[np.ndarray, np.ndarray]: Features and target of the dataset
    """

    # Generate random samples
    X = np.random.uniform(-2*np.pi, 2*np.pi, (n_samples, 1)).astype(np.float32)

    # Compute the target
    y = np.sin(X) + np.random.normal(0, noise, (n_samples, 1)).astype(np.float32)
    
    # Return the dataset
    return X, y

# %%
# Generate the synthetic dataset of a sine function with some gaussian noise
X, y = generate_sine_dataset(n_samples, noise=data_noise)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=train_test_split_pct, random_state=seed)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=train_valid_split, random_state=seed)

# Print the dataset information
print('Training set:', X_train.shape, y_train.shape)
print('Validation set:', X_valid.shape, y_valid.shape)
print('Testing set:', X_test.shape, y_test.shape)
# Out:
# Training set: (640, 1) (640, 1)
# Validation set: (160, 1) (160, 1)
# Testing set: (200, 1) (200, 1)

# %% [markdown]
# ### Data visualization

# %%
utils.plot_data(
    datasets = [
        {'points': np.array(list(zip(X_train, y_train))), 'label': "Sine function", 'color': "blue", 'size': 10, 'plot_type': 'scatter'},
    ],
    title = "Sine Function Dataset",
    xlabel = "X",
    ylabel = "y"
)

# %% [markdown]
# ### Building the model

# %%
# Create the model
model = FeedForward([
    layers.Dense(num_units=256, activation=activations.Tanh()),
    layers.Dense(num_units=128, activation=activations.Tanh()),
    layers.Dense(num_units=32, activation=activations.Tanh()),
    layers.Dense(num_units=1)
])

# Initialize the optimizer
optimizer = optimizers.Adam(
    learning_rate = learning_rate,
    weight_decay = 0.01
)

# Initialize the error function
error_fn = loss_functions.MeanSquareError()

# %%
# Call the model with a first batch to initialize the weights
# This is not necessary, but it is useful to know the input size
model(X_train[:batch_size]);

# %%
# Display the model summary
model.summary()
# Out:
# Neural Network (ID: 0)
#
# --------------------------------------------------------------------------------
# Layer (type)                            Output Shape        Trainable params #
# ================================================================================
# dense_1 (Dense)                         (32, 256)           512
# --------------------------------------------------------------------------------
# dense_2 (Dense)                         (32, 128)           32896
# --------------------------------------------------------------------------------
# dense_3 (Dense)                         (32, 32)            4128
# --------------------------------------------------------------------------------
# dense_4 (Dense)                         (32, 1)             33
# ================================================================================
# Total trainable parameters: 37569
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Training the model

# %%
# Fit the model
history = model.fit(
    X_train = X_train, 
    y_train = y_train,
    optimizer = optimizer,
    loss_fn = error_fn,
    X_valid = X_valid,
    y_valid = y_valid,
    batch_size = batch_size,
    epochs = epochs,
    metrics = [metrics.mean_absolute_error],
    callbacks = [callbacks.EarlyStopping(monitor="val_loss", patience=10)]
)
# Out:
# Epoch 1/300 --> loss: 0.4434 - mean absolute error: 0.5370 | Validation loss: 0.3665 - Validation mean absolute error: 0.5331
# Epoch 2/300 --> loss: 0.3176 - mean absolute error: 0.4366 | Validation loss: 0.2486 - Validation mean absolute error: 0.4353
# Epoch 3/300 --> loss: 0.2107 - mean absolute error: 0.3405 | Validation loss: 0.1654 - Validation mean absolute error: 0.3447
# Epoch 4/300 --> loss: 0.1462 - mean absolute error: 0.2864 | Validation loss: 0.1267 - Validation mean absolute error: 0.2831
# Epoch 5/300 --> loss: 0.1253 - mean absolute error: 0.2740 | Validation loss: 0.1214 - Validation mean absolute error: 0.2704
# Epoch 6/300 --> loss: 0.1195 - mean absolute error: 0.2719 | Validation loss: 0.1209 - Validation mean absolute error: 0.2697
# Epoch 7/300 --> loss: 0.1203 - mean absolute error: 0.2732 | Validation loss: 0.1183 - Validation mean absolute error: 0.2701
# Epoch 8/300 --> loss: 0.1205 - mean absolute error: 0.2726 | Validation loss: 0.1173 - Validation mean absolute error: 0.2700
# Epoch 9/300 --> loss: 0.1158 - mean absolute error: 0.2681 | Validation loss: 0.1165 - Validation mean absolute error: 0.2670
# Epoch 10/300 --> loss: 0.1144 - mean absolute error: 0.2653 | Validation loss: 0.1155 - Validation mean absolute error: 0.2648
# Epoch 11/300 --> loss: 0.1177 - mean absolute error: 0.2637 | Validation loss: 0.1152 - Validation mean absolute error: 0.2642
# Epoch 12/300 --> loss: 0.1115 - mean absolute error: 0.2679 | Validation loss: 0.1130 - Validation mean absolute error: 0.2663
# Epoch 13/300 --> loss: 0.1130 - mean absolute error: 0.2626 | Validation loss: 0.1152 - Validation mean absolute error: 0.2652
# Epoch 14/300 --> loss: 0.1082 - mean absolute error: 0.2581 | Validation loss: 0.1099 - Validation mean absolute error: 0.2584
# Epoch 15/300 --> loss: 0.1072 - mean absolute error: 0.2658 | Validation loss: 0.1116 - Validation mean absolute error: 0.2645
# Epoch 16/300 --> loss: 0.1101 - mean absolute error: 0.2568 | Validation loss: 0.1087 - Validation mean absolute error: 0.2588
# Epoch 17/300 --> loss: 0.1044 - mean absolute error: 0.2534 | Validation loss: 0.1054 - Validation mean absolute error: 0.2532
# Epoch 18/300 --> loss: 0.1029 - mean absolute error: 0.2521 | Validation loss: 0.1042 - Validation mean absolute error: 0.2531
# Epoch 19/300 --> loss: 0.1041 - mean absolute error: 0.2500 | Validation loss: 0.1041 - Validation mean absolute error: 0.2523
# Epoch 20/300 --> loss: 0.1003 - mean absolute error: 0.2478 | Validation loss: 0.1013 - Validation mean absolute error: 0.2488
# Epoch 21/300 --> loss: 0.1004 - mean absolute error: 0.2460 | Validation loss: 0.1015 - Validation mean absolute error: 0.2487
# Epoch 22/300 --> loss: 0.1012 - mean absolute error: 0.2468 | Validation loss: 0.1010 - Validation mean absolute error: 0.2502
# Epoch 23/300 --> loss: 0.1023 - mean absolute error: 0.2520 | Validation loss: 0.1086 - Validation mean absolute error: 0.2577
# Epoch 24/300 --> loss: 0.0976 - mean absolute error: 0.2427 | Validation loss: 0.0956 - Validation mean absolute error: 0.2422
# Epoch 25/300 --> loss: 0.0963 - mean absolute error: 0.2475 | Validation loss: 0.1047 - Validation mean absolute error: 0.2532
# Epoch 78/300 --> loss: 0.0286 - mean absolute error: 0.1313 | Validation loss: 0.0265 - Validation mean absolute error: 0.1286
# Epoch 79/300 --> loss: 0.0285 - mean absolute error: 0.1298 | Validation loss: 0.0252 - Validation mean absolute error: 0.1256
# Epoch 80/300 --> loss: 0.0279 - mean absolute error: 0.1342 | Validation loss: 0.0259 - Validation mean absolute error: 0.1296
# Epoch 81/300 --> loss: 0.0270 - mean absolute error: 0.1297 | Validation loss: 0.0246 - Validation mean absolute error: 0.1252
# Epoch 82/300 --> loss: 0.0287 - mean absolute error: 0.1299 | Validation loss: 0.0241 - Validation mean absolute error: 0.1254
# Epoch 83/300 --> loss: 0.0271 - mean absolute error: 0.1285 | Validation loss: 0.0254 - Validation mean absolute error: 0.1257
# Epoch 84/300 --> loss: 0.0272 - mean absolute error: 0.1281 | Validation loss: 0.0247 - Validation mean absolute error: 0.1242
# Epoch 85/300 --> loss: 0.0266 - mean absolute error: 0.1283 | Validation loss: 0.0237 - Validation mean absolute error: 0.1237
# Epoch 86/300 --> loss: 0.0268 - mean absolute error: 0.1353 | Validation loss: 0.0258 - Validation mean absolute error: 0.1299
# Epoch 87/300 --> loss: 0.0266 - mean absolute error: 0.1285 | Validation loss: 0.0235 - Validation mean absolute error: 0.1230
# Epoch 88/300 --> loss: 0.0266 - mean absolute error: 0.1301 | Validation loss: 0.0268 - Validation mean absolute error: 0.1285
# Epoch 89/300 --> loss: 0.0269 - mean absolute error: 0.1327 | Validation loss: 0.0275 - Validation mean absolute error: 0.1320
# Epoch 90/300 --> loss: 0.0265 - mean absolute error: 0.1263 | Validation loss: 0.0241 - Validation mean absolute error: 0.1228
# Epoch 91/300 --> loss: 0.0267 - mean absolute error: 0.1265 | Validation loss: 0.0245 - Validation mean absolute error: 0.1236
# Epoch 92/300 --> loss: 0.0255 - mean absolute error: 0.1317 | Validation loss: 0.0242 - Validation mean absolute error: 0.1261
# Epoch 93/300 --> loss: 0.0276 - mean absolute error: 0.1275 | Validation loss: 0.0253 - Validation mean absolute error: 0.1252
# Epoch 94/300 --> loss: 0.0256 - mean absolute error: 0.1310 | Validation loss: 0.0239 - Validation mean absolute error: 0.1252
# Epoch 95/300 --> loss: 0.0275 - mean absolute error: 0.1442 | Validation loss: 0.0337 - Validation mean absolute error: 0.1445
# Epoch 96/300 --> loss: 0.0307 - mean absolute error: 0.1331 | Validation loss: 0.0250 - Validation mean absolute error: 0.1280
# Epoch 97/300 --> loss: 0.0280 - mean absolute error: 0.1261 | Validation loss: 0.0248 - Validation mean absolute error: 0.1243
# Early stopping: stopping training after 96 epochs.

# %%
# Plot the training and validation loss
utils.plot_history(history["loss"], history["val_loss"], "Training and Validation Loss", "Epoch", "Loss")

# %% [markdown]
# ### Evaluation

# %%
# Predict the labels
predictions = model(X_test)

# %%
# Calculate the mean absolute error
mae = metrics.mean_absolute_error(y_test, predictions)

# Print the mean absolute error
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.1152395888155429

# %%
# Plot the sine function and the model predictions
utils.plot_data(
    datasets = [
        {'points': np.array(list(zip(X_train, y_train))), 'label': "Sine function", 'color': "blue", 'size': 10, 'plot_type': 'scatter'},
        {'points': np.array(list(zip(X_test, predictions))), 'label': "Learned function", 'color': "red", 'plot_type': 'line'}
    ],
    title = "Sine Function and Model Predictions",
    xlabel = "X",
    ylabel = "y"
)
